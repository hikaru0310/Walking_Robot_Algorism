# %%
using Plots
using ControlSystems

gr()
# Out:
# Plots.GRBackend()

# %%
#入力は脚先位置とその速度
#leg support vector
#sup_point_l=[0.1 0.2
            #0.3 0.3]
#vl=[0.3 0.3]
#sup_point_r=[0.1 0.2
            #0.2 0.2]
#vr=[0.3 0.3]
#sup_point_c=[0.0 0.1
            #0.0 0.0]
#vc=[0.3 0.3]

# %%
#support time 0.5
t0=0.6025
te=1.1
#t0=100
#te=200

#xの遊脚軌道

#条件ベクトル
x0=0.2
xe=0.2
v0=-0.2
ve=-0.2
ae=0.0

#A=[x0; xe; v0; ve; ae]

#B=[t0^4 t0^3 t0^2 t0 1;
#    te^4 te^3 te^2 te 1;
#    4t0^3 3t0^2 2t0 1 0;
#    4te^3 3te^2 2te 1 0;
#    12te^2 6te 2 0 0]
A=[x0; xe; v0; ve]

B=[t0^3 t0^2 t0 1
    te^3 te^2 te 1
    3t0^2 2t0 1 0
    3te^2 2te 1 0]

C=inv(B)*A

dt=0.01 #離散時間
t=[i for i in t0:dt:te]; #描画時間
#x=C[1]*.^(t,4)+C[2]*.^(t,3)+C[3]*.^(t,2)+C[4]*t+C[5] #位置
#v=4*C[1]*.^(t,3)+3*C[2]*.^(t,2)+2*C[3]*t+C[4] #速度
#a=12*C[1]*.^(t,2)+6*C[2]*t+2*C[3] #加速度
x=C[1]*.^(t,3)+C[2]*.^(t,2)+C[3]*t+C[4] #位置
v=3*C[1]*.^(t,2)+2*C[2]*t+C[3] #速度
a=6*C[1]*t+2*C[2]

# %%
plot(t,x,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4000">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4001">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4002">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   52.3536,363.094 52.3536,13.2835
#   "/>
# ...

# %%
plot(t,v,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4100)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4102">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4102)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   52.3536,363.094 52.3536,13.2835
#   "/>
# ...

# %%
plot(t,a,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4202">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   52.3536,363.094 52.3536,13.2835
#   "/>
# ...

# %%
#zの遊脚軌道
zh=-0.18
z0=-0.23
ze=-0.23
v0=0.0
ve=0.0

#support time 0.5
t0=0.6025
te=1.1
th=round((te-t0)/2+t0,7)

A_z=[zh; z0; ze; v0; ve]

B_z=[th^4 th^3 th^2 th 1
    t0^4 t0^3 t0^2 t0 1
    te^4 te^3 te^2 te 1
    4t0^3 3t0^2 2t0 1 0
    4te^3 3te^2 2te 1 0]
C_z=inv(B_z)*A_z

z=C_z[1]*.^(t,4)+C_z[2]*.^(t,3)+C_z[3]*.^(t,2)+C_z[4]*t+C_z[5] #位置
v_z=4*C_z[1]*.^(t,3)+3*C_z[2]*.^(t,2)+2*C_z[3]*t+C_z[4] #速度
a_z=12*C_z[1]*.^(t,2)+6*C_z[2]*t+2*C_z[3]; #加速度

# %%
maximum(z)
# Out:
# -0.1800025251568993

# %%
plot(t,z,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1802">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   52.3536,363.094 52.3536,13.2835
#   "/>
# ...

# %%
plot(t,v_z,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1500)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1502">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   52.3536,363.094 52.3536,13.2835
#   "/>
# ...

# %%
plot(t,a_z,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1602">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   52.3536,363.094 52.3536,13.2835
#   "/>
# ...

# %%
th
# Out:
# 0.8512500000000001

# %%
plot(x,z)
ac=[0.25 0.0]
bc=[0.3 0.3]
plot!(ac,bc,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 39.3701,368.504 592.126,368.504 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7802">
#     <rect x="39" y="7" width="554" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.0141,363.094 55.0141,13.2835
#   "/>
# ...

# %%
g=[1 for y in 0:0.01:0.5]
plot(x,g,z)
ac=[0.25 0.0]
bc=[0.3 0.3]
ay=[0.3 0.3]
plot!(ac,ay,bc,st=:scatter)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7900)" points="
# 135.433,368.504 496.063,368.504 496.063,7.87402 135.433,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7902">
#     <rect x="135" y="7" width="362" height="362"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7900)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   135.433,268.398 299.973,126.219
#   "/>
# ...
